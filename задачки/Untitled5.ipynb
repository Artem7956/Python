# %%
monuments=['z','o','zh','k','e']
monarch=['AM','Ek','Ni','P']
palace=['Put','Nib','Kot','Kol']

for i in monuments:
    for j in monarch:
        for k in palace:
            print(i,j,k)

# MA=[1,2,3,4,5] #Место АМ 
# MN=[1,2,3,4] #Место Ник
# ME=[1,2,3,4] #Место E
# MP=[1,2,3,4,5] #Место P

# PO=[2,3,4,5] #Место пам o
# PZ=[1,2,3,4,5] #Место пам z
# PZH=[2,3,4,5] #Место пам zh
# PK=[1,2,3,4,5] #Место пам K
# PE=[1,2,3,4,5] #Место пам E

# for i1 in MA:
#     for i2 in MN:
#         for i3 in ME:
#             for i4 in MP:
#                 for j1 in PO:
#                     for j2 in PZ:
#                         for j3 in PZH:
#                             for j4 in PK:
#                                 for j5 in PK:
#                                     if abs(i2-i1)==1 and abs(j1-j4)==1:
#                                         print('АМ={0}, Ник={1},Место Екатерины={2}, Место Петра={3}'.format(i1,i2,i3,i4))


# monuments = ['з','о','ж','к','е']
# monarch = ['Петр','Екатерина','АМ','Николай']
# bunts=['Пугачев','Болотников','Булавин','Муравьев','Разин']
# palace=['Путевой','Нибиру','Котедж','Коломенский']

# for i1 in monuments:
#     for i2 in monarch:
#         for i3 in bunts:
#             for i4 in palace:
#                 #if i1=='ж' and i3=='Булавин':
#                 print('index={}',i1,i2,i3,i4)
# Out:
# z AM Put
# z AM Nib
# z AM Kot
# z AM Kol
# z Ek Put
# z Ek Nib
# z Ek Kot
# z Ek Kol
# z Ni Put
# z Ni Nib
# z Ni Kot
# z Ni Kol
# z P Put
# z P Nib
# z P Kot
# z P Kol
# o AM Put
# o AM Nib
# o AM Kot
# o AM Kol
# o Ek Put
# o Ek Nib
# o Ek Kot
# o Ek Kol
# o Ni Put
# o Ni Nib
# o Ni Kot
# o Ni Kol
# o P Put
# o P Nib
# o P Kot
# o P Kol
# zh AM Put
# zh AM Nib
# zh AM Kot
# zh AM Kol
# zh Ek Put
# zh Ek Nib
# zh Ek Kot
# zh Ek Kol
# zh Ni Put
# zh Ni Nib
# zh Ni Kot
# zh Ni Kol
# zh P Put
# zh P Nib
# zh P Kot
# zh P Kol
# k AM Put
# k AM Nib
# k AM Kot
# k AM Kol
# k Ek Put
# k Ek Nib
# k Ek Kot
# k Ek Kol
# k Ni Put
# k Ni Nib
# k Ni Kot
# k Ni Kol
# k P Put
# k P Nib
# k P Kot
# k P Kol
# e AM Put
# e AM Nib
# e AM Kot
# e AM Kol
# e Ek Put
# e Ek Nib
# e Ek Kot
# e Ek Kol
# e Ni Put
# e Ni Nib
# e Ni Kot
# e Ni Kol
# e P Put
# e P Nib
# e P Kot
# e P Kol
